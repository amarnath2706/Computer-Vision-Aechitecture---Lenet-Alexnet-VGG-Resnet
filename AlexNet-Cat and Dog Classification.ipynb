# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten,\
 Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
import numpy as np
np.random.seed(1000)

# %%
# (3) Create a sequential model
model = Sequential()
# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(224,224,3), kernel_size=(11,11),\
 strides=(4,4), padding='valid'))
model.add(Activation('relu'))
# Pooling 
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation before passing it to the next layer
model.add(BatchNormalization())
# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(11,11), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation
model.add(BatchNormalization())
# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Batch Normalisation
model.add(BatchNormalization())
# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Batch Normalisation
model.add(BatchNormalization())
# 5th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
# Batch Normalisation
model.add(BatchNormalization())
# Passing it to a dense layer
model.add(Flatten())
# 1st Dense Layer
model.add(Dense(4096, input_shape=(224*224*3,)))
model.add(Activation('relu'))
# Add Dropout to prevent overfitting
model.add(Dropout(0.4))
# Batch Normalisation
model.add(BatchNormalization())

# 2nd Dense Layer
model.add(Dense(4096))
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.4))
# Batch Normalisation
model.add(BatchNormalization())

# 3rd Dense Layer
model.add(Dense(1000))
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.4))
# Batch Normalisation
model.add(BatchNormalization())

# Output Layer
model.add(Dense(2))
model.add(Activation('softmax'))


# (4) Compile 
model.compile(loss='categorical_crossentropy', optimizer='adam',\
 metrics=['accuracy'])

# %%
# Part 2 - Fitting the CNN to the images

from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory('C:\\Users\\Asus-2020\\Downloads\\Cat and Dog\\train',
                                                 target_size = (224, 224),
                                                 batch_size = 16,
                                                 class_mode = 'categorical')

test_set = test_datagen.flow_from_directory('C:\\Users\\Asus-2020\\Downloads\\Cat and Dog\\test',
                                            target_size = (224, 224),
                                            batch_size = 16,
                                            class_mode = 'categorical')

r=model.fit_generator(training_set,
                         steps_per_epoch = len(training_set),
                         epochs = 50,
                         validation_data = test_set,    
                         validation_steps = len(test_set))
# Out:
# Found 8005 images belonging to 2 classes.
# Found 2023 images belonging to 2 classes.
# Epoch 1/50
#   2/501 [..............................] - ETA: 16s - loss: 1.1690 - accuracy: 0.6250WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0249s vs `on_train_batch_end` time: 0.0419s). Check your callbacks.
# 501/501 [==============================] - 97s 194ms/step - loss: 0.8948 - accuracy: 0.5273 - val_loss: 0.8051 - val_accuracy: 0.4953
# Epoch 2/50
# 501/501 [==============================] - 89s 178ms/step - loss: 0.7443 - accuracy: 0.5317 - val_loss: 0.6870 - val_accuracy: 0.5502
# Epoch 3/50
# 501/501 [==============================] - 90s 179ms/step - loss: 0.7358 - accuracy: 0.5408 - val_loss: 0.6939 - val_accuracy: 0.5536
# Epoch 4/50
# 501/501 [==============================] - 90s 179ms/step - loss: 0.7240 - accuracy: 0.5492 - val_loss: 0.7512 - val_accuracy: 0.5037
# Epoch 5/50
# 501/501 [==============================] - 91s 182ms/step - loss: 0.7341 - accuracy: 0.5369 - val_loss: 0.7140 - val_accuracy: 0.5872
# Epoch 6/50
# 501/501 [==============================] - 90s 180ms/step - loss: 0.7238 - accuracy: 0.5518 - val_loss: 0.7939 - val_accuracy: 0.5823
# Epoch 7/50
# 501/501 [==============================] - 91s 181ms/step - loss: 0.7208 - accuracy: 0.5614 - val_loss: 0.7713 - val_accuracy: 0.5358
# Epoch 8/50
# 501/501 [==============================] - 91s 181ms/step - loss: 0.7073 - accuracy: 0.5768 - val_loss: 0.8775 - val_accuracy: 0.5818
# Epoch 9/50
# 501/501 [==============================] - 91s 181ms/step - loss: 0.6937 - accuracy: 0.5903 - val_loss: 0.9100 - val_accuracy: 0.5161
# Epoch 10/50
# 501/501 [==============================] - 90s 180ms/step - loss: 0.6971 - accuracy: 0.5941 - val_loss: 0.8808 - val_accuracy: 0.5690
# Epoch 11/50
# 501/501 [==============================] - 89s 177ms/step - loss: 0.6920 - accuracy: 0.5934 - val_loss: 0.6889 - val_accuracy: 0.5833
# Epoch 12/50
# 501/501 [==============================] - 86s 171ms/step - loss: 0.6935 - accuracy: 0.5851 - val_loss: 55.5336 - val_accuracy: 0.4933
# Epoch 13/50
# 501/501 [==============================] - 85s 171ms/step - loss: 0.6871 - accuracy: 0.5988 - val_loss: 0.6776 - val_accuracy: 0.6441
# Epoch 14/50
# 501/501 [==============================] - 86s 172ms/step - loss: 0.6706 - accuracy: 0.6102 - val_loss: 0.6961 - val_accuracy: 0.5408
# Epoch 15/50
# 501/501 [==============================] - 86s 171ms/step - loss: 0.6854 - accuracy: 0.6037 - val_loss: 0.7753 - val_accuracy: 0.5739
# Epoch 16/50
# 501/501 [==============================] - 86s 171ms/step - loss: 0.6766 - accuracy: 0.6122 - val_loss: 0.6325 - val_accuracy: 0.6530
# Epoch 17/50
# 501/501 [==============================] - 85s 171ms/step - loss: 0.6440 - accuracy: 0.6507 - val_loss: 0.7150 - val_accuracy: 0.6036
# Epoch 18/50
# 501/501 [==============================] - 86s 172ms/step - loss: 0.6284 - accuracy: 0.6661 - val_loss: 0.6180 - val_accuracy: 0.6866
# Epoch 19/50
# 501/501 [==============================] - 86s 171ms/step - loss: 0.6264 - accuracy: 0.6647 - val_loss: 1.5115 - val_accuracy: 0.5225
# Epoch 20/50
# 501/501 [==============================] - 86s 172ms/step - loss: 0.6261 - accuracy: 0.6557 - val_loss: 0.6227 - val_accuracy: 0.6693
# Epoch 21/50
# 501/501 [==============================] - 86s 172ms/step - loss: 0.6257 - accuracy: 0.6598 - val_loss: 0.9315 - val_accuracy: 0.6050
# Epoch 22/50
# 501/501 [==============================] - 86s 171ms/step - loss: 0.6160 - accuracy: 0.6711 - val_loss: 1.4154 - val_accuracy: 0.5887
# Epoch 23/50
# 501/501 [==============================] - 87s 173ms/step - loss: 0.5946 - accuracy: 0.6914 - val_loss: 0.5786 - val_accuracy: 0.7064
# Epoch 24/50
# 501/501 [==============================] - 86s 171ms/step - loss: 0.5889 - accuracy: 0.6962 - val_loss: 0.6598 - val_accuracy: 0.6075
# Epoch 25/50
# 501/501 [==============================] - 86s 171ms/step - loss: 0.5859 - accuracy: 0.6968 - val_loss: 0.6323 - val_accuracy: 0.6965
# Epoch 26/50
# 501/501 [==============================] - 86s 172ms/step - loss: 0.5853 - accuracy: 0.6916 - val_loss: 0.7115 - val_accuracy: 0.5645
# Epoch 27/50
# 501/501 [==============================] - 86s 171ms/step - loss: 0.6230 - accuracy: 0.6645 - val_loss: 0.6169 - val_accuracy: 0.7009
# Epoch 28/50
# 501/501 [==============================] - 86s 171ms/step - loss: 0.5965 - accuracy: 0.6864 - val_loss: 0.7153 - val_accuracy: 0.5610
# Epoch 29/50
# 501/501 [==============================] - 86s 171ms/step - loss: 0.5701 - accuracy: 0.7059 - val_loss: 0.6071 - val_accuracy: 0.7192
# Epoch 30/50
# 501/501 [==============================] - 86s 172ms/step - loss: 0.5632 - accuracy: 0.7192 - val_loss: 0.5213 - val_accuracy: 0.7563
# Epoch 31/50
# 501/501 [==============================] - 86s 173ms/step - loss: 0.5422 - accuracy: 0.7322 - val_loss: 0.5798 - val_accuracy: 0.7271
# Epoch 32/50
# 501/501 [==============================] - 86s 171ms/step - loss: 0.5568 - accuracy: 0.7237 - val_loss: 0.4955 - val_accuracy: 0.7751
# Epoch 33/50
# 501/501 [==============================] - 86s 172ms/step - loss: 0.5347 - accuracy: 0.7445 - val_loss: 0.6913 - val_accuracy: 0.6861
# Epoch 34/50
# 501/501 [==============================] - 86s 172ms/step - loss: 0.5271 - accuracy: 0.7483 - val_loss: 0.6009 - val_accuracy: 0.6960
# Epoch 35/50
# 501/501 [==============================] - 86s 172ms/step - loss: 0.5220 - accuracy: 0.7502 - val_loss: 0.5040 - val_accuracy: 0.7622
# Epoch 36/50
# 501/501 [==============================] - 86s 172ms/step - loss: 0.4983 - accuracy: 0.7711 - val_loss: 0.5129 - val_accuracy: 0.7519
# Epoch 37/50
# 501/501 [==============================] - 86s 172ms/step - loss: 0.5375 - accuracy: 0.7228 - val_loss: 1.0413 - val_accuracy: 0.4815
# Epoch 38/50
# 501/501 [==============================] - 86s 171ms/step - loss: 0.5644 - accuracy: 0.7199 - val_loss: 0.6348 - val_accuracy: 0.6387
# Epoch 39/50
# 501/501 [==============================] - 86s 172ms/step - loss: 0.4934 - accuracy: 0.7730 - val_loss: 0.4667 - val_accuracy: 0.7815
# Epoch 40/50
# 501/501 [==============================] - 86s 172ms/step - loss: 0.5028 - accuracy: 0.7570 - val_loss: 0.5477 - val_accuracy: 0.6950
# Epoch 41/50
# 501/501 [==============================] - 86s 172ms/step - loss: 0.4950 - accuracy: 0.7651 - val_loss: 0.5921 - val_accuracy: 0.7237
# Epoch 42/50
# 501/501 [==============================] - 86s 171ms/step - loss: 0.4994 - accuracy: 0.7660 - val_loss: 0.4835 - val_accuracy: 0.7706
# Epoch 43/50
# 501/501 [==============================] - 86s 171ms/step - loss: 0.4727 - accuracy: 0.7790 - val_loss: 0.4863 - val_accuracy: 0.7766
# Epoch 44/50
# 501/501 [==============================] - 86s 172ms/step - loss: 0.4426 - accuracy: 0.7998 - val_loss: 0.4858 - val_accuracy: 0.7731
# Epoch 45/50
# 501/501 [==============================] - 86s 173ms/step - loss: 0.4508 - accuracy: 0.7889 - val_loss: 0.6049 - val_accuracy: 0.7291
# Epoch 46/50
# 501/501 [==============================] - 85s 170ms/step - loss: 0.4624 - accuracy: 0.7823 - val_loss: 0.4758 - val_accuracy: 0.7860
# Epoch 47/50
# 501/501 [==============================] - 86s 171ms/step - loss: 0.4180 - accuracy: 0.8110 - val_loss: 0.4436 - val_accuracy: 0.8077
# Epoch 48/50
# 501/501 [==============================] - 87s 173ms/step - loss: 0.4264 - accuracy: 0.8085 - val_loss: 0.7731 - val_accuracy: 0.6055
# Epoch 49/50
# 501/501 [==============================] - 87s 173ms/step - loss: 0.4272 - accuracy: 0.8090 - val_loss: 0.4149 - val_accuracy: 0.8122
# Epoch 50/50
# 501/501 [==============================] - 85s 171ms/step - loss: 0.3843 - accuracy: 0.8286 - val_loss: 0.5363 - val_accuracy: 0.7578

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 54, 54, 96)        34944
# _________________________________________________________________
# activation_9 (Activation)    (None, 54, 54, 96)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 27, 27, 96)        0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 27, 27, 96)        384
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 17, 17, 256)       2973952
# _________________________________________________________________
# activation_10 (Activation)   (None, 17, 17, 256)       0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 6, 6, 384)         885120
# _________________________________________________________________
# activation_11 (Activation)   (None, 6, 6, 384)         0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 6, 6, 384)         1536
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 4, 4, 384)         1327488
# _________________________________________________________________
# activation_12 (Activation)   (None, 4, 4, 384)         0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 4, 4, 384)         1536
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 2, 2, 256)         884992
# _________________________________________________________________
# activation_13 (Activation)   (None, 2, 2, 256)         0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 1, 1, 256)         1024
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 4096)              1052672
# _________________________________________________________________
# activation_14 (Activation)   (None, 4096)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 4096)              16384
# _________________________________________________________________
# dense_5 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# activation_15 (Activation)   (None, 4096)              0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 4096)              16384
# _________________________________________________________________
# dense_6 (Dense)              (None, 1000)              4097000
# _________________________________________________________________
# activation_16 (Activation)   (None, 1000)              0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 1000)              4000
# _________________________________________________________________
# dense_7 (Dense)              (None, 2)                 2002
# _________________________________________________________________
# activation_17 (Activation)   (None, 2)                 0
# =================================================================
# Total params: 28,081,754
# Trainable params: 28,060,618
# Non-trainable params: 21,136
# _________________________________________________________________

# %%
# plot the loss
import matplotlib.pyplot as plt
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig('LossVal_loss')

# plot the accuracy
plt.plot(r.history['accuracy'], label='train acc')
plt.plot(r.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
plt.savefig('AccVal_acc')

# %%
# Part 3 - Making new predictions
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('C:\\Users\\Asus-2020\Downloads\\Cat and Dog\\test\\cats\\cat.4488.jpg', target_size = (224, 224))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)
#training_set.class_indices
print(result)
if result[0][0] == 1:
    prediction = 'Cat'
    print(prediction)
else:
    prediction = 'Dog'
    print(prediction)
# Out:
# [[1. 0.]]
# Cat
